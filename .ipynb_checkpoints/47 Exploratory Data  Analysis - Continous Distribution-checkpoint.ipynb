# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
import pylab as py

import warnings
warnings.filterwarnings('ignore')
sns.set(style='white')

# %% [markdown]
# ## Churn Prediction Dataset

# %%
# reading csv file
data = pd.read_csv('churn_prediction.csv')

# %%
# first look at the data
data.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     2101   66   Male         0.0  self_employed   187.0
# 1            2     2348   35   Male         0.0  self_employed     NaN
# 2            4     2194   31   Male         0.0       salaried   146.0
# 3            5     2329   90    NaN         NaN  self_employed  1020.0
# 4            6     1579   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  current_balance  ...  \
# 0                     2          755          1458.71  ...
# 1                     2         3214          5390.37  ...
# 2                     2           41          3913.16  ...
# 3                     2          582          2291.91  ...
# 4                     3          388           927.72  ...
#
#    average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# 0                        1458.71                         1449.07
# 1                        7799.26                        12419.41
# 2                        4910.17                         2815.94
# 3                        2084.54                         1006.54
# 4                        1643.31                         1871.12
#
#    current_month_credit  previous_month_credit  current_month_debit  \
# 0                  0.20                   0.20                 0.20
# 1                  0.56                   0.56              5486.27
# 2                  0.61                   0.61              6046.73
# 3                  0.47                   0.47                 0.47
# 4                  0.33                 714.61               588.62
#
#    previous_month_debit  current_month_balance  previous_month_balance  churn  \
# 0                  0.20                1458.71                 1458.71      0
# 1                100.56                6496.78                 8787.61      0
# 2                259.23                5006.28                 5070.14      0
# 3               2143.33                2291.91                 1669.79      1
# 4               1538.06                1157.15                 1677.16      1
#
#    last_transaction
# 0        2019-05-21
# 1        2019-11-01
# 2               NaT
# 3        2019-08-06
# 4        2019-11-03
#
# [5 rows x 21 columns]

# %%
# getting the shape of data 
data.shape
# Out:
# (28382, 21)

# %%
# features in data
data.columns
# Out:
# Index(['customer_id', 'vintage', 'age', 'gender', 'dependents', 'occupation',
#        'city', 'customer_nw_category', 'branch_code', 'current_balance',
#        'previous_month_end_balance', 'average_monthly_balance_prevQ',
#        'average_monthly_balance_prevQ2', 'current_month_credit',
#        'previous_month_credit', 'current_month_debit', 'previous_month_debit',
#        'current_month_balance', 'previous_month_balance', 'churn',
#        'last_transaction'],
#       dtype='object')

# %%
# getting the data types for each feature
data.dtypes
# Out:
# customer_id                         int64
# vintage                             int64
# age                                 int64
# gender                             object
# dependents                        float64
# occupation                         object
# city                              float64
# customer_nw_category                int64
# branch_code                         int64
# current_balance                   float64
# previous_month_end_balance        float64
# average_monthly_balance_prevQ     float64
# average_monthly_balance_prevQ2    float64
# current_month_credit              float64
# previous_month_credit             float64
# current_month_debit               float64
# previous_month_debit              float64
# current_month_balance             float64
# previous_month_balance            float64
# churn                               int64
# last_transaction                   object
# dtype: object

# %% [markdown]
# ## Age of Customers

# %%
# plotting histogram
plt.figure(dpi= 140)
plt.hist(data['age'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('histogram : Age of people')
plt.show()

# %% [markdown]
# - A **Histogram** visualises the distribution of data over a continous interval.
# - Each bar in a histogram represents the tabulated **frequency** at each **interval/bin**.
# - In simple words **height (y-axis)** represents the **frequency** for respective **bin (interval)**.
# - Most Customers lie in the age between 40 -50.

# %%
age = data["age"]

# %%
# calculating points of standard deviation
a_mean = age.mean()
a_median = age.median()
a_stdev = age.mean() - age.std(), age.mean() + age.std()

# %%
# checking 
a_mean, a_median, a_stdev
# Out:
# (48.208336269466564, 46.0, (30.401172896500047, 66.01549964243308))

# %% [markdown]
# - Mean value of age in 48.208336269466564
# - Median value for age is 46.0
# - Spread for first standard deviation is (30.40117289650014, 66.01549964243299)

# %%
# plotting KDE plot with descriptives
plt.figure(dpi = 140)
sns.kdeplot(age, shade= True)
sns.scatterplot( [a_mean], [0], color='red', label='mean')
sns.scatterplot( [a_median], [0], color='green', label='median')
sns.lineplot( a_stdev, [0,0], color='black', label='standard deviation')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title(" KDE Plot with descrptives : Age of people who churned")
plt.show()

# %% [markdown]
# - KDE indicates that age of Customers follow a distribution which is similar to **Normal Distribution**
# - Suprisingly there are more that expected **Older Customer** in our dataset.

# %%
## qq plot explain
sm.qqplot(age, line='s')
py.show()

# %% [markdown]
# - **Larger values** are **not as large/extreme** as expected from a Normal Distribution.
# - **Smaller values** are **not as smalle/extreme**as expected from a Normal Distribution.

# %%
data['age'].skew()
# Out:
# 0.33058929557517264

# %% [markdown]
# - **Skewness** is around 0.33.
# - Age of Customers follows a **Normal** like Distribution.

# %%
data['age'].kurtosis()
# Out:
# -0.16866785691275865

# %% [markdown]
# - **Kurtosis Value** is also close to Zero.
# - This means tails are not as **dense** as compared to Normal Distribution.
# - There are less values availabe along the tails.

# %% [markdown]
# ## Vintage

# %%
vintage = data['vintage']

# %%
# calculating measures
v_mean = vintage.mean()
v_median = vintage.median()
v_mode = vintage.mode()

# %%
# checking
v_mean, v_median, v_mode
# Out:
# (2091.1441054189277,
#  2154.0,
#  0    2251
#  1    2260
#  Name: vintage, dtype: int64)

# %% [markdown]
# - **Mean value** of vintage is 2091.1441054189277
# - **Median value** for vintage is 2154.0
# - **Mode value** for vintage is 2251 and 2260. Both of them have same frequency

# %%
print(data[data['vintage']==2251].shape[0])
print(data[data['vintage']==2260].shape[0])
# Out:
# 69
# 69

# %% [markdown]
# - The freqency for 2251 and 2260 is 69.
# - **Both** of them qualify to be the **mode** value (most frequent value) for the dataset.

# %%
# plotting histogram
plt.figure(dpi =140)
plt.hist(data['vintage'])
plt.xlabel("Vintage")
plt.ylabel("Frequency")
plt.title("Histogram :-  Vintage")
plt.show()

# %% [markdown]
# - Clearly Histogram indicates that distribution is **Left Skewed** for Vintage.
# - More customers have interaction with the bank from More days in compare to the customer who are new for the bank.

# %%
# plotting KDE plot with descriptives
plt.figure(dpi =140)
sns.kdeplot(data['vintage'], shade = True)
sns.scatterplot( [v_mean], [0], color='red', label='mean')
sns.scatterplot( [v_median], [0], color='green', label='median')
sns.scatterplot( [v_mode[0]], [0], color='blue', label='mode1')
sns.scatterplot( [v_mode[1]], [0], color='blue', label='mode2')

plt.xlabel("Vintage")
plt.ylabel("Frequency")
plt.title("KDE Plot with descriptives : Vintage of Customers")
plt.show()

# %% [markdown]
# - KDE indicates that Vintage of Customers follow a distribution which is **Left Skewed**.
# - **Mean and Median** are **higher** than the **Mode** value.
# - Tall on the **left** side of the distribution is **longer**.

# %%
# explian Skewness
data['vintage'].skew()
# Out:
# -1.3889357082821185

# %% [markdown]
#  - **Negative Skewness** indicates **Negatively Skewed**.
#  - **Negative skewws** is also known as **Left Skewed Distribution**.

# %%
# Kurtosis Positive
data['vintage'].kurtosis()
# Out:
# 2.7234245375227926

# %% [markdown]
# - **Postive Kurtosis** indicates **Leptokurtic Distribution**.
# - Distribution is **longer** in compare to Normal Distribution.
# - High presence of **extrme values**.

# %%
## qq plot explain
sm.qqplot(data['vintage'], line='s')
py.show()

# %% [markdown]
# - Larger values are not as large as expected from a Normal Distribution.
# - Smaller values are lesser in magnitude as compared to a Normal Distribution.
